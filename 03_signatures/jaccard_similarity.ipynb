# %%
import os, glob
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt

# %%
signature_fn = sorted(glob.glob('results/*/*/*.txt'))
signature_dict = {'_'.join([fn.split('/')[i] for i in [-3, -1]]).replace('.txt', '') : fn for fn in signature_fn}
for key in signature_dict:
    signature_dict[key] = pd.read_csv(signature_dict[key])
    print(key, signature_dict[key])
# Out:
# GSE136689_early    mmusculus hsapiens
# 0       Dab2     DAB2
# 1      Map1b    MAP1B
# 2       Irx1     IRX1
# 3      Rbm24    RBM24
# 4      Sox11    SOX11
# ..       ...      ...
# 65     Nop58    NOP58
# 66     Aldoa    ALDOA
# 67       Mmd      MMD
# 68   Slc16a3  SLC16A3
# 69    Mpped2   MPPED2
#
# [70 rows x 2 columns]
# GSE136689_late    mmusculus hsapiens
# 0        Id2      ID2
# 1     Homer2   HOMER2
# 2       Manf     MANF
# 3       Bex2     BEX1
# 4       Bex2     BEX2
# 5       Bex1     BEX1
# 6       Bex1     BEX2
# 7      Nr2f2    NR2F2
# 8       Wnt2     WNT2
# 9       Alx1     ALX1
# 10     Csrp2    CSRP2
# 11     Sfrp1    SFRP1
# 12      Krt8     KRT8
# 13     Krt18    KRT18
# 14    Phlda1   PHLDA1
# 15      Osr1     OSR1
# 16      Mycn     MYCN
# 17      Rbp1     RBP1
# 18     Gata6    GATA6
# 19     Sfrp5    SFRP5
# 20     Rras2    RRAS2
# 21     Pmp22    PMP22
# 22     Cox17    COX17
# 23    Popdc2   POPDC2
# 24       Ddt     DDTL
# 25       Ddt      DDT
# 26   Smarcd3  SMARCD3
# 27      Ly6e     LY6E
# 28      Nrp1     NRP1
# 29     Dusp9    DUSP9
# 30      Rgs5     RGS5
# 31      Arg1     ARG1
# 32     Foxf1    FOXF1
# 33   Aldh1a2  ALDH1A2
# 34     Hoxa1    HOXA1
# 35     Hand2    HAND2
# 36     Meis1    MEIS1
# 37    Phlda2   PHLDA2
# 38     Gata5    GATA5
# 39      Car4      CA4
# 40     Hoxb1    HOXB1
# 41       Mdk      MDK
# 42      Peg3     PEG3
# GSE162534_early    mmusculus hsapiens
# 0       Sqle     SQLE
# 1      Fdft1    FDFT1
# 2      Snrpn    SNRPN
# 3       Crb3     CRB3
# 4     Pmaip1   PMAIP1
# ..       ...      ...
# 66     Uchl1    UCHL1
# 67    Spint2   SPINT2
# 68    Dnmt3b   DNMT3B
# 69      Fgf5     FGF5
# 70      Nav2     NAV2
#
# [71 rows x 2 columns]
# GSE162534_late     mmusculus  hsapiens
# 0        Cdh2      CDH2
# 1       Greb1     GREB1
# 2    Tnfrsf19  TNFRSF19
# 3       Rspo3     RSPO3
# 4       Epha1     EPHA1
# ..        ...       ...
# 130      Cst3      CST3
# 131    Mogat2    MOGAT2
# 132  Serpinh1  SERPINH1
# 133       Sp5       SP5
# 134      Peg3      PEG3
#
# [135 rows x 2 columns]
# GSE201257_early    mmusculus hsapiens
# 0    Phactr1  PHACTR1
# 1      Map1b    MAP1B
# 2    Ppp1r1a  PPP1R1A
# 3    Spata13  SPATA13
# 4      Ednrb    EDNRB
# ..       ...      ...
# 93      Bmp7     BMP7
# 94     Celf2    CELF2
# 95    Arpc1b   ARPC1B
# 96     Gdpd5    GDPD5
# 97    Tom1l1   TOM1L1
#
# [98 rows x 2 columns]
# GSE201257_late    mmusculus hsapiens
# 0     Efemp2   EFEMP2
# 1      Vcam1    VCAM1
# 2    Smarca2  SMARCA2
# 3        Fos      FOS
# 4      Wnt5a    WNT5A
# ..       ...      ...
# 69   Tnfaip6  TNFAIP6
# 70    Pcolce   PCOLCE
# 71   Tmem119  TMEM119
# 72      Tbx2     TBX2
# 73     Mfap4    MFAP4
#
# [74 rows x 2 columns]
# GSE229103_early    mmusculus hsapiens
# 0      Greb1    GREB1
# 1       Cdx1     CDX1
# 2       Odc1     ODC1
# 3      Map1b    MAP1B
# 4       Rrm2     RRM2
# ..       ...      ...
# 78      Chd3     CHD3
# 79     Hoxb9    HOXB9
# 80     Hoxb8    HOXB8
# 81       Sp5      SP5
# 82    Tubb4b   TUBB4B
#
# [83 rows x 2 columns]
# GSE229103_late    mmusculus hsapiens
# 0       Fbn2     FBN2
# 1     Maged2   MAGED2
# 2      Rspo3    RSPO3
# 3      Wnt5a    WNT5A
# 4     Pcdh19   PCDH19
# ..       ...      ...
# 70    Rnf213   RNF213
# 71       Sct      SCT
# 72     Tcf15    TCF15
# 73      Peg3     PEG3
# 74     Nrarp    NRARP
#
# [75 rows x 2 columns]

# %%
adata = sc.read_h5ad('results/pseudobulk.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 30 × 8
#     obs: 'GEO'
#     var: 'stage', 'GEO'
#     uns: 'GEO_colors', 'stage_colors'

# %%
jac = pd.DataFrame(0., index = adata.var_names, columns = adata.var_names)
for i, ix in enumerate(jac.columns):
    g1 = set(signature_dict[ix].mmusculus)
    for j, jx in enumerate(jac.columns):
        g2 = set(signature_dict[jx].mmusculus)
        jac.loc[ix, jx] = len(g1 & g2) / len(g1 | g2)

# %%
dset_palette = dict(zip(adata.var.GEO.cat.categories, adata.uns['GEO_colors']))
col_colors = adata.var.GEO.map(dset_palette)

g = sns.clustermap(
    jac,
    mask = np.eye(jac.shape[0]),
    row_cluster = False,
    col_cluster = False,
    cmap = 'binary',
    annot = True,
    annot_kws = {'fontsize' : 8.5},
    col_colors = col_colors,
    row_colors = col_colors,
    figsize = (6, 6))

for ax in (g.ax_cbar, g.ax_col_dendrogram, g.ax_row_dendrogram):
    ax.remove()

for ax in (g.ax_heatmap, g.ax_col_colors, g.ax_row_colors):
    ax.set_xticks([])
    ax.set_yticks([])

dset_labels = {
    'GSE136689' : 'Splanchnic\nMesoderm',
    'GSE162534' : 'Primitive\nStreak',
    'GSE201257' : 'Neural Crest',
    'GSE229103' : 'Neuromesodermal\nProgenitor'
    }

ticks = np.arange(0., jac.shape[0], 2) + 1
ticklabels = adata.var.GEO.cat.categories.map(dset_labels)
g.ax_row_colors.set_yticks(ticks, ticklabels)
g.ax_col_colors.set_xticks(ticks, ticklabels, rotation = 45, rotation_mode = 'anchor', ha = 'left', va = 'center')
g.ax_row_colors.tick_params('y', left = False, labelleft = True)
g.ax_col_colors.tick_params('x', bottom = False, labelbottom = False, labeltop = True, pad = 10)
g.figure.suptitle('Jaccard Similarity', y = 1.05)
plt.show()
