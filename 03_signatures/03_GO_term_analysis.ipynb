# %%
import os, glob
import numpy as np
import pandas as pd
import gseapy as gp

# %%
signature_fn = sorted(glob.glob('results/*/*/*.txt'))
signature_dict = {'_'.join([fn.split('/')[i] for i in [-3, -1]]).replace('.txt', '') : fn for fn in signature_fn}
for key in signature_dict:
    signature_dict[key] = pd.read_csv(signature_dict[key])
    print(key, signature_dict[key])
# Out:
# GSE136689_early    mmusculus hsapiens
# 0       Dab2     DAB2
# 1      Map1b    MAP1B
# 2       Irx1     IRX1
# 3      Rbm24    RBM24
# 4      Sox11    SOX11
# ..       ...      ...
# 65     Nop58    NOP58
# 66     Aldoa    ALDOA
# 67       Mmd      MMD
# 68   Slc16a3  SLC16A3
# 69    Mpped2   MPPED2
#
# [70 rows x 2 columns]
# GSE136689_late    mmusculus hsapiens
# 0        Id2      ID2
# 1     Homer2   HOMER2
# 2       Manf     MANF
# 3       Bex2     BEX1
# 4       Bex2     BEX2
# 5       Bex1     BEX1
# 6       Bex1     BEX2
# 7      Nr2f2    NR2F2
# 8       Wnt2     WNT2
# 9       Alx1     ALX1
# 10     Csrp2    CSRP2
# 11     Sfrp1    SFRP1
# 12      Krt8     KRT8
# 13     Krt18    KRT18
# 14    Phlda1   PHLDA1
# 15      Osr1     OSR1
# 16      Mycn     MYCN
# 17      Rbp1     RBP1
# 18     Gata6    GATA6
# 19     Sfrp5    SFRP5
# 20     Rras2    RRAS2
# 21     Pmp22    PMP22
# 22     Cox17    COX17
# 23    Popdc2   POPDC2
# 24       Ddt     DDTL
# 25       Ddt      DDT
# 26   Smarcd3  SMARCD3
# 27      Ly6e     LY6E
# 28      Nrp1     NRP1
# 29     Dusp9    DUSP9
# 30      Rgs5     RGS5
# 31      Arg1     ARG1
# 32     Foxf1    FOXF1
# 33   Aldh1a2  ALDH1A2
# 34     Hoxa1    HOXA1
# 35     Hand2    HAND2
# 36     Meis1    MEIS1
# 37    Phlda2   PHLDA2
# 38     Gata5    GATA5
# 39      Car4      CA4
# 40     Hoxb1    HOXB1
# 41       Mdk      MDK
# 42      Peg3     PEG3
# GSE162534_early    mmusculus hsapiens
# 0       Sqle     SQLE
# 1      Fdft1    FDFT1
# 2      Snrpn    SNRPN
# 3       Crb3     CRB3
# 4     Pmaip1   PMAIP1
# ..       ...      ...
# 66     Uchl1    UCHL1
# 67    Spint2   SPINT2
# 68    Dnmt3b   DNMT3B
# 69      Fgf5     FGF5
# 70      Nav2     NAV2
#
# [71 rows x 2 columns]
# GSE162534_late     mmusculus  hsapiens
# 0        Cdh2      CDH2
# 1       Greb1     GREB1
# 2    Tnfrsf19  TNFRSF19
# 3       Rspo3     RSPO3
# 4       Epha1     EPHA1
# ..        ...       ...
# 130      Cst3      CST3
# 131    Mogat2    MOGAT2
# 132  Serpinh1  SERPINH1
# 133       Sp5       SP5
# 134      Peg3      PEG3
#
# [135 rows x 2 columns]
# GSE201257_early    mmusculus hsapiens
# 0    Phactr1  PHACTR1
# 1      Map1b    MAP1B
# 2    Ppp1r1a  PPP1R1A
# 3    Spata13  SPATA13
# 4      Ednrb    EDNRB
# ..       ...      ...
# 93      Bmp7     BMP7
# 94     Celf2    CELF2
# 95    Arpc1b   ARPC1B
# 96     Gdpd5    GDPD5
# 97    Tom1l1   TOM1L1
#
# [98 rows x 2 columns]
# GSE201257_late    mmusculus hsapiens
# 0     Efemp2   EFEMP2
# 1      Vcam1    VCAM1
# 2    Smarca2  SMARCA2
# 3        Fos      FOS
# 4      Wnt5a    WNT5A
# ..       ...      ...
# 69   Tnfaip6  TNFAIP6
# 70    Pcolce   PCOLCE
# 71   Tmem119  TMEM119
# 72      Tbx2     TBX2
# 73     Mfap4    MFAP4
#
# [74 rows x 2 columns]
# GSE229103_early    mmusculus hsapiens
# 0      Greb1    GREB1
# 1       Cdx1     CDX1
# 2       Odc1     ODC1
# 3      Map1b    MAP1B
# 4       Rrm2     RRM2
# ..       ...      ...
# 78      Chd3     CHD3
# 79     Hoxb9    HOXB9
# 80     Hoxb8    HOXB8
# 81       Sp5      SP5
# 82    Tubb4b   TUBB4B
#
# [83 rows x 2 columns]
# GSE229103_late    mmusculus hsapiens
# 0       Fbn2     FBN2
# 1     Maged2   MAGED2
# 2      Rspo3    RSPO3
# 3      Wnt5a    WNT5A
# 4     Pcdh19   PCDH19
# ..       ...      ...
# 70    Rnf213   RNF213
# 71       Sct      SCT
# 72     Tcf15    TCF15
# 73      Peg3     PEG3
# 74     Nrarp    NRARP
#
# [75 rows x 2 columns]
# HCAEmbryonicHindlimb_early    hsapiens mmusculus
# 0   MT-ND4L   mt-Nd4l
# 1      CD24     Cd24a
# 2     WFDC2     Wfdc2
# 3      SOX9      Sox9
# 4       HBZ     Hba-x
# 5     MECOM     Mecom
# 6     PMP22     Pmp22
# 7    COL2A1    Col2a1
# 8    COL9A2    Col9a2
# 9       CPE       Cpe
# 10  ADAMTS6   Adamts6
# 11    HMGA1     Hmga1
# 12   COL9A1    Col9a1
# 13  RHOBTB3   Rhobtb3
# 14      MIA       Mia
# 15  S100A11   S100a11
# 16     CNN2      Cnn2
# 17     FRZB      Frzb
# 18  COL11A1   Col11a1
# HCAEmbryonicHindlimb_late    hsapiens mmusculus
# 0    MT-CO1    mt-Co1
# 1    MT-CO2    mt-Co2
# 2   MT-ATP6   mt-Atp6
# 3    MT-CO3    mt-Co3
# 4    MT-ND3    mt-Nd3
# ..      ...       ...
# 73   IGFBP4    Igfbp4
# 74     HES1      Hes1
# 75      BOC       Boc
# 76   COL3A1    Col3a1
# 77   COL5A2    Col5a2
#
# [78 rows x 2 columns]

# %%
for key, signature in signature_dict.items():
    df = gp.enrichr(
        gene_list = signature.mmusculus.tolist(),
        gene_sets = ['GO_Biological_Process_2025', 'GO_Cellular_Component_2025', 'GO_Molecular_Function_2025'],
        organism = 'Mouse',
        outdir = None,
        cutoff = .05
        ).results[['Term', 'Adjusted P-value']]
    df['Term'] = df.Term.str.extract(r'\((GO:\d+)\)')
    df = df.loc[df['Adjusted P-value'] < .05].sort_values('Adjusted P-value')

    if df.empty:
        print(key, 'No significant GO terms found.')
    else:
        gseapy_dir_fn = '/'.join(['results', key.split('_')[0], 'gseapy'])
        os.makedirs(gseapy_dir_fn, exist_ok = True)
        df.to_csv(f'{gseapy_dir_fn}/{key.split('_')[1]}.csv', index = False)
        print(key, df.head(), '\n')
# Out:
# GSE136689_early          Term  Adjusted P-value
# 0  GO:0030182      4.704480e-07
# 1  GO:0048699      4.704480e-07
# 2  GO:0045597      1.548557e-06
# 3  GO:0003229      3.944875e-06
# 4  GO:0055010      1.721078e-05
#
# GSE136689_late            Term  Adjusted P-value
# 0    GO:0045893      5.219443e-08
# 1    GO:0045944      8.695259e-07
# 2    GO:0006357      1.446692e-05
# 599  GO:0043565      7.464384e-05
# 3    GO:0007507      1.529709e-04
#
# GSE162534_early          Term  Adjusted P-value
# 0  GO:0016126          0.001437
# 1  GO:1902653          0.010305
# 2  GO:0006695          0.010305
# 3  GO:0006694          0.010305
# 4  GO:0008203          0.010305
#
# GSE162534_late          Term  Adjusted P-value
# 0  GO:0007507      6.601746e-14
# 1  GO:0060976      2.871516e-10
# 2  GO:0006357      6.408609e-10
# 3  GO:0008284      1.757656e-09
# 4  GO:0007369      1.885291e-09
#
# GSE201257_early             Term  Adjusted P-value
# 1023  GO:1990837      2.330689e-08
# 1024  GO:0003690      2.330689e-08
# 0     GO:0009952      2.694879e-08
# 1025  GO:0043565      7.912856e-08
# 1026  GO:0000978      1.093803e-06
#
# GSE201257_late            Term  Adjusted P-value
# 782  GO:0062023      5.765975e-09
# 857  GO:1990837      2.327020e-06
# 0    GO:0048706      4.794241e-06
# 858  GO:0043565      1.039537e-05
# 859  GO:0003690      1.519107e-05
#
# GSE229103_early            Term  Adjusted P-value
# 0    GO:0009952          0.000140
# 1    GO:0006357          0.000140
# 737  GO:0000977          0.000316
# 736  GO:0043565          0.000316
# 735  GO:1990837          0.000316
#
# GSE229103_late             Term  Adjusted P-value
# 0     GO:0045892      2.587330e-10
# 1     GO:0000122      2.587330e-10
# 2     GO:0006357      1.322305e-09
# 3     GO:0007507      1.089006e-07
# 1001  GO:0043565      3.109538e-07
#
# HCAEmbryonicHindlimb_early            Term  Adjusted P-value
# 0    GO:0045229      6.521185e-08
# 1    GO:0043062      6.521185e-08
# 2    GO:0030198      8.570493e-07
# 3    GO:0001501      6.961286e-04
# 200  GO:0005788      2.928616e-03
#
# HCAEmbryonicHindlimb_late            Term  Adjusted P-value
# 776  GO:0062023      1.960612e-07
# 777  GO:0005788      6.472253e-06
# 0    GO:0030199      1.619987e-05
# 1    GO:0097435      3.093908e-05
# 778  GO:0070013      2.455289e-04
