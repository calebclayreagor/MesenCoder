# %%
import os, glob
import numpy as np
import pandas as pd
import seaborn as sns
import scanpy as sc
import anndata as ad

# %%
dset_summary = pd.read_csv('../data/summary.csv', index_col = 0)
species_dict = dset_summary['species'].to_dict()
adata_fn = sorted(glob.glob('../data/processed/*/*.h5ad'))
adata_dict = {fn.split('/')[-1].split('_')[0] : fn for fn in adata_fn}
for key in adata_dict:
    adata_dict[key] = sc.read_h5ad(adata_dict[key])
    print(key, adata_dict[key])
# Out:
# GSE136689 AnnData object with n_obs × n_vars = 10097 × 17462
#     obs: 'Stages', 'Clusters', 'Type', 'LineageAnnotations', 'celltype'
#     var: 'n_cells', 'm', 'v', 'n_obs', 'res', 'lp', 'lpa', 'qv', 'highly_variable'
#     uns: 'Stages_colors', 'celltype_colors', 'diffmap_evals', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_diffmap', 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# GSE162534 AnnData object with n_obs × n_vars = 8725 × 19013
#     obs: 'sample', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden', 'celltype'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'm', 'v', 'n_obs', 'res', 'lp', 'lpa', 'qv', 'highly_variable'
#     uns: 'celltype_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# GSE201257 AnnData object with n_obs × n_vars = 8842 × 21676
#     obs: 'plates', 'devtime', 'location', 'n_genes_by_counts', 'total_counts', 'total_counts_ERCC', 'pct_counts_ERCC', 'doublet_scores', 'leiden', 'CytoTRACE', 'Gut_neuron', 'Sensory', 'Symp', 'enFib', 'ChC', 'Gut_glia', 'NCC', 'Mesenchyme', 'Melanocytes', 'SatGlia', 'SC', 'BCC', 'conflict', 'assignments', 'Hub', 'Hub_leiden', 'celltype'
#     var: 'ERCC', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'm', 'v', 'n_obs', 'res', 'lp', 'lpa', 'qv', 'highly_variable'
#     uns: 'Hub_colors', 'assignments_colors', 'celltype_colors', 'devtime_colors', 'leiden', 'leiden_colors', 'leiden_sizes', 'location_colors', 'log1p', 'neighbors', 'paga', 'umap'
#     obsm: 'X_diff', 'X_pca', 'X_umap'
#     layers: 'palantir_imp', 'scaled'
#     obsp: 'connectivities', 'distances'
# GSE229103 AnnData object with n_obs × n_vars = 11255 × 20088
#     obs: 'sample', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'leiden', 'T+ Sox2+', 'celltype'
#     var: 'n_cells', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'm', 'v', 'n_obs', 'res', 'lp', 'lpa', 'qv', 'highly_variable'
#     uns: 'T+ Sox2+_colors', 'celltype_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'sample_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
# HCAEmbryonicHindlimb AnnData object with n_obs × n_vars = 125955 × 26522
#     obs: 'batch', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'region', 'tissue', 'adj_stage', 'adj_sample', 'leiden', 'S_score', 'G2M_score', 'phase', 'leiden_R', 'celltype', 'celltype_original'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'highly_variableWSSS_THYst8796437', 'highly_variableWSSS_THYst8796442', 'highly_variable5478STDY7935101', 'highly_variable5478STDY7935102', 'highly_variableWSSS_THYst8796439', 'highly_variableWSSS_THYst9384956', 'highly_variable5478STDY7717491', 'highly_variableWSSS_THYst9384953', 'highly_variable5478STDY7717492', 'highly_variableWSSS_THYst9384955', 'highly_variable5386STDY7537944', 'highly_variableWSSS_THYst9384954', 'highly_variableFCAImmP7536759', 'highly_variable5478STDY7980349', 'highly_variableWSSS_THYst8796438', 'highly_variable5478STDY7652318', 'highly_variableWSSS_THYst8796441', 'highly_variableFCAImmP7536758', 'highly_variableWSSS_THYst9384957', 'highly_variable5478STDY7980348', 'highly_variable5386STDY7557337', 'highly_variable5386STDY7557336', 'highly_variableWSSS_THYst9384958', 'highly_variableWSSS_THYst8796440', 'highly_variable5386STDY7557335', 'highly_variable_n', 'highly_variable'
#     uns: 'adj_stage_colors', 'batch_colors', 'celltype_colors', 'celltype_sizes', 'leiden', 'leiden_R_colors', 'leiden_colors', 'leiden_sizes', 'log1p', 'majority_voting_colors', 'markers_celltype', 'markers_new_celltype', 'neighbors', 'new_celltype_sizes', 'paga', 'pca', 'phase_colors', 'pre-annotation_colors', 'rank_genes_groups', 'region_colors', 'tissue_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata_bulk_dict = adata_dict.copy()
for key in adata_dict:
    adata_key = adata_dict[key][~adata_dict[key].obs.celltype.isna()]
    adata_bulk_dict[key] = sc.get.aggregate(adata_key, 'celltype', 'mean')
    print(key, adata_bulk_dict[key])
# Out:
# GSE136689 AnnData object with n_obs × n_vars = 8 × 17462
#     obs: 'celltype'
#     var: 'n_cells', 'm', 'v', 'n_obs', 'res', 'lp', 'lpa', 'qv', 'highly_variable'
#     layers: 'mean'
# GSE162534 AnnData object with n_obs × n_vars = 3 × 19013
#     obs: 'celltype'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'm', 'v', 'n_obs', 'res', 'lp', 'lpa', 'qv', 'highly_variable'
#     layers: 'mean'
# GSE201257 AnnData object with n_obs × n_vars = 13 × 21676
#     obs: 'celltype'
#     var: 'ERCC', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'm', 'v', 'n_obs', 'res', 'lp', 'lpa', 'qv', 'highly_variable'
#     layers: 'mean'
# GSE229103 AnnData object with n_obs × n_vars = 7 × 20088
#     obs: 'celltype'
#     var: 'n_cells', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'm', 'v', 'n_obs', 'res', 'lp', 'lpa', 'qv', 'highly_variable'
#     layers: 'mean'
# HCAEmbryonicHindlimb AnnData object with n_obs × n_vars = 9 × 26522
#     obs: 'celltype'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'highly_variableWSSS_THYst8796437', 'highly_variableWSSS_THYst8796442', 'highly_variable5478STDY7935101', 'highly_variable5478STDY7935102', 'highly_variableWSSS_THYst8796439', 'highly_variableWSSS_THYst9384956', 'highly_variable5478STDY7717491', 'highly_variableWSSS_THYst9384953', 'highly_variable5478STDY7717492', 'highly_variableWSSS_THYst9384955', 'highly_variable5386STDY7537944', 'highly_variableWSSS_THYst9384954', 'highly_variableFCAImmP7536759', 'highly_variable5478STDY7980349', 'highly_variableWSSS_THYst8796438', 'highly_variable5478STDY7652318', 'highly_variableWSSS_THYst8796441', 'highly_variableFCAImmP7536758', 'highly_variableWSSS_THYst9384957', 'highly_variable5478STDY7980348', 'highly_variable5386STDY7557337', 'highly_variable5386STDY7557336', 'highly_variableWSSS_THYst9384958', 'highly_variableWSSS_THYst8796440', 'highly_variable5386STDY7557335', 'highly_variable_n', 'highly_variable'
#     layers: 'mean'

# %%
signature_fn = sorted(glob.glob('../03_signatures/results/*/biomart/*.txt'))
signature_dict = {'_'.join([fn.split('/')[i] for i in [-3, -1]]).replace('.txt', '') : fn for fn in signature_fn}
for key in signature_dict:
    signature_dict[key] = pd.read_csv(signature_dict[key])
    print(key, signature_dict[key])
# Out:
# GSE136689_early    mmusculus hsapiens
# 0       Dab2     DAB2
# 1      Map1b    MAP1B
# 2       Irx1     IRX1
# 3      Rbm24    RBM24
# 4      Sox11    SOX11
# ..       ...      ...
# 65     Nop58    NOP58
# 66     Aldoa    ALDOA
# 67       Mmd      MMD
# 68   Slc16a3  SLC16A3
# 69    Mpped2   MPPED2
#
# [70 rows x 2 columns]
# GSE136689_late    mmusculus hsapiens
# 0        Id2      ID2
# 1     Homer2   HOMER2
# 2       Manf     MANF
# 3       Bex2     BEX1
# 4       Bex2     BEX2
# 5       Bex1     BEX1
# 6       Bex1     BEX2
# 7      Nr2f2    NR2F2
# 8       Wnt2     WNT2
# 9       Alx1     ALX1
# 10     Csrp2    CSRP2
# 11     Sfrp1    SFRP1
# 12      Krt8     KRT8
# 13     Krt18    KRT18
# 14    Phlda1   PHLDA1
# 15      Osr1     OSR1
# 16      Mycn     MYCN
# 17      Rbp1     RBP1
# 18     Gata6    GATA6
# 19     Sfrp5    SFRP5
# 20     Rras2    RRAS2
# 21     Pmp22    PMP22
# 22     Cox17    COX17
# 23    Popdc2   POPDC2
# 24       Ddt     DDTL
# 25       Ddt      DDT
# 26   Smarcd3  SMARCD3
# 27      Ly6e     LY6E
# 28      Nrp1     NRP1
# 29     Dusp9    DUSP9
# 30      Rgs5     RGS5
# 31      Arg1     ARG1
# 32     Foxf1    FOXF1
# 33   Aldh1a2  ALDH1A2
# 34     Hoxa1    HOXA1
# 35     Hand2    HAND2
# 36     Meis1    MEIS1
# 37    Phlda2   PHLDA2
# 38     Gata5    GATA5
# 39      Car4      CA4
# 40     Hoxb1    HOXB1
# 41       Mdk      MDK
# 42      Peg3     PEG3
# GSE162534_early    mmusculus hsapiens
# 0       Sqle     SQLE
# 1      Fdft1    FDFT1
# 2      Snrpn    SNRPN
# 3       Crb3     CRB3
# 4     Pmaip1   PMAIP1
# ..       ...      ...
# 66     Uchl1    UCHL1
# 67    Spint2   SPINT2
# 68    Dnmt3b   DNMT3B
# 69      Fgf5     FGF5
# 70      Nav2     NAV2
#
# [71 rows x 2 columns]
# GSE162534_late     mmusculus  hsapiens
# 0        Cdh2      CDH2
# 1       Greb1     GREB1
# 2    Tnfrsf19  TNFRSF19
# 3       Rspo3     RSPO3
# 4       Epha1     EPHA1
# ..        ...       ...
# 130      Cst3      CST3
# 131    Mogat2    MOGAT2
# 132  Serpinh1  SERPINH1
# 133       Sp5       SP5
# 134      Peg3      PEG3
#
# [135 rows x 2 columns]
# GSE201257_early    mmusculus hsapiens
# 0    Phactr1  PHACTR1
# 1      Map1b    MAP1B
# 2    Ppp1r1a  PPP1R1A
# 3    Spata13  SPATA13
# 4      Ednrb    EDNRB
# ..       ...      ...
# 93      Bmp7     BMP7
# 94     Celf2    CELF2
# 95    Arpc1b   ARPC1B
# 96     Gdpd5    GDPD5
# 97    Tom1l1   TOM1L1
#
# [98 rows x 2 columns]
# GSE201257_late    mmusculus hsapiens
# 0     Efemp2   EFEMP2
# 1      Vcam1    VCAM1
# 2    Smarca2  SMARCA2
# 3        Fos      FOS
# 4      Wnt5a    WNT5A
# ..       ...      ...
# 69   Tnfaip6  TNFAIP6
# 70    Pcolce   PCOLCE
# 71   Tmem119  TMEM119
# 72      Tbx2     TBX2
# 73     Mfap4    MFAP4
#
# [74 rows x 2 columns]
# GSE229103_early    mmusculus hsapiens
# 0      Greb1    GREB1
# 1       Cdx1     CDX1
# 2       Odc1     ODC1
# 3      Map1b    MAP1B
# 4       Rrm2     RRM2
# ..       ...      ...
# 78      Chd3     CHD3
# 79     Hoxb9    HOXB9
# 80     Hoxb8    HOXB8
# 81       Sp5      SP5
# 82    Tubb4b   TUBB4B
#
# [83 rows x 2 columns]
# GSE229103_late    mmusculus hsapiens
# 0       Fbn2     FBN2
# 1     Maged2   MAGED2
# 2      Rspo3    RSPO3
# 3      Wnt5a    WNT5A
# 4     Pcdh19   PCDH19
# ..       ...      ...
# 70    Rnf213   RNF213
# 71       Sct      SCT
# 72     Tcf15    TCF15
# 73      Peg3     PEG3
# 74     Nrarp    NRARP
#
# [75 rows x 2 columns]
# HCAEmbryonicHindlimb_early    hsapiens mmusculus
# 0   MT-ND4L   mt-Nd4l
# 1      CD24     Cd24a
# 2     WFDC2     Wfdc2
# 3      SOX9      Sox9
# 4       HBZ     Hba-x
# 5     MECOM     Mecom
# 6     PMP22     Pmp22
# 7    COL2A1    Col2a1
# 8    COL9A2    Col9a2
# 9       CPE       Cpe
# 10  ADAMTS6   Adamts6
# 11    HMGA1     Hmga1
# 12   COL9A1    Col9a1
# 13  RHOBTB3   Rhobtb3
# 14      MIA       Mia
# 15  S100A11   S100a11
# 16     CNN2      Cnn2
# 17     FRZB      Frzb
# 18  COL11A1   Col11a1
# HCAEmbryonicHindlimb_late    hsapiens mmusculus
# 0    MT-CO1    mt-Co1
# 1    MT-CO2    mt-Co2
# 2   MT-ATP6   mt-Atp6
# 3    MT-CO3    mt-Co3
# 4    MT-ND3    mt-Nd3
# ..      ...       ...
# 73   IGFBP4    Igfbp4
# 74     HES1      Hes1
# 75      BOC       Boc
# 76   COL3A1    Col3a1
# 77   COL5A2    Col5a2
#
# [78 rows x 2 columns]

# %%
df_ix = np.concatenate([adata_bulk_dict[key].obs.celltype for key in adata_bulk_dict])
assert np.unique(df_ix).size == df_ix.size
df_col = np.asarray(signature_dict.keys())
df = pd.DataFrame(0., index = df_ix, columns = df_col)
for key in adata_bulk_dict:
    adata = adata_bulk_dict[key]
    for col in df.columns:
        signature = signature_dict[col][species_dict[key]]
        df.loc[adata.obs.celltype, col] = sc.tl.score_genes(
            adata, signature, ctrl_as_ref = True, score_name = col,
            copy = True, layer = 'mean').obs[col]
# Out:
# WARNING: genes are not in var_names and ignored: Index(['Mrps6'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Prdm12', 'Wnt1', 'Foxd3', 'Hbb-y'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Fgf17', 'Jpt1'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Msgn1'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['mt-Nd4l', 'Hba-x'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['mt-Co1', 'mt-Co2', 'mt-Atp6', 'mt-Co3', 'mt-Nd3', 'mt-Nd4', 'mt-Nd5',
#        'mt-Cytb', 'Rps26'],
#       dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Hoxc8', 'Wnt1'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Esr1', 'Ccl6'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Hoxc8', 'Jpt1'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Hba-x'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Ifitm6'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Jpt1'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Epb41l3', 'Rnf213'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['mt-Nd4l'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['mt-Co1', 'mt-Co2', 'mt-Atp6', 'mt-Co3', 'mt-Nd3', 'mt-Nd4', 'mt-Nd5',
#        'mt-Cytb'],
#       dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['Ifitm6'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['TBXT', 'CFC1B', 'MOGAT2'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['HES3', 'CDX2', 'TBXT'], dtype='object')

# %%
df_obs = np.concatenate([[key] * adata_bulk_dict[key].shape[0] for key in adata_bulk_dict])
df_obs = pd.DataFrame(df_obs, index = df.index, columns = ['source'])
df_var = np.flip(np.vstack(df.columns.str.split('_')), 1)
df_var = pd.DataFrame(df_var, index = df.columns, columns = ['stage', 'source'])
uns_dict = {
    'stage_colors' : list(sns.color_palette('Oranges', df_var.stage.nunique()).as_hex()),
    'source_colors' : list(sns.color_palette('cubehelix', df_var.source.nunique()).as_hex())
    }

# %%
adata = ad.AnnData(df, obs = df_obs, var = df_var, uns = uns_dict)
adata
# Out:
# AnnData object with n_obs × n_vars = 40 × 10
#     obs: 'source'
#     var: 'stage', 'source'
#     uns: 'stage_colors', 'source_colors'

# %%
adata.write('results/adata_pseudobulk_signatures.h5ad')
