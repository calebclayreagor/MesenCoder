# %%
import os, glob
import numpy as np
import pandas as pd
import gseapy as gp
import matplotlib.pyplot as plt

# %%
signature_fn = sorted(glob.glob('../03_signatures/results/*/biomart/*.txt'))
signature_dict = {'_'.join([fn.split('/')[i] for i in [-3, -1]]).replace('.txt', '') : fn for fn in signature_fn}
for key in signature_dict:
    signature_dict[key] = pd.read_csv(signature_dict[key])
    print(key, signature_dict[key])
# Out:
# GSE136689_early    mmusculus hsapiens
# 0       Dab2     DAB2
# 1      Map1b    MAP1B
# 2       Irx1     IRX1
# 3      Rbm24    RBM24
# 4      Sox11    SOX11
# ..       ...      ...
# 65     Nop58    NOP58
# 66     Aldoa    ALDOA
# 67       Mmd      MMD
# 68   Slc16a3  SLC16A3
# 69    Mpped2   MPPED2
#
# [70 rows x 2 columns]
# GSE136689_late    mmusculus hsapiens
# 0        Id2      ID2
# 1     Homer2   HOMER2
# 2       Manf     MANF
# 3       Bex2     BEX1
# 4       Bex2     BEX2
# 5       Bex1     BEX1
# 6       Bex1     BEX2
# 7      Nr2f2    NR2F2
# 8       Wnt2     WNT2
# 9       Alx1     ALX1
# 10     Csrp2    CSRP2
# 11     Sfrp1    SFRP1
# 12      Krt8     KRT8
# 13     Krt18    KRT18
# 14    Phlda1   PHLDA1
# 15      Osr1     OSR1
# 16      Mycn     MYCN
# 17      Rbp1     RBP1
# 18     Gata6    GATA6
# 19     Sfrp5    SFRP5
# 20     Rras2    RRAS2
# 21     Pmp22    PMP22
# 22     Cox17    COX17
# 23    Popdc2   POPDC2
# 24       Ddt     DDTL
# 25       Ddt      DDT
# 26   Smarcd3  SMARCD3
# 27      Ly6e     LY6E
# 28      Nrp1     NRP1
# 29     Dusp9    DUSP9
# 30      Rgs5     RGS5
# 31      Arg1     ARG1
# 32     Foxf1    FOXF1
# 33   Aldh1a2  ALDH1A2
# 34     Hoxa1    HOXA1
# 35     Hand2    HAND2
# 36     Meis1    MEIS1
# 37    Phlda2   PHLDA2
# 38     Gata5    GATA5
# 39      Car4      CA4
# 40     Hoxb1    HOXB1
# 41       Mdk      MDK
# 42      Peg3     PEG3
# GSE162534_early    mmusculus hsapiens
# 0       Sqle     SQLE
# 1      Fdft1    FDFT1
# 2      Snrpn    SNRPN
# 3       Crb3     CRB3
# 4     Pmaip1   PMAIP1
# ..       ...      ...
# 66     Uchl1    UCHL1
# 67    Spint2   SPINT2
# 68    Dnmt3b   DNMT3B
# 69      Fgf5     FGF5
# 70      Nav2     NAV2
#
# [71 rows x 2 columns]
# GSE162534_late     mmusculus  hsapiens
# 0        Cdh2      CDH2
# 1       Greb1     GREB1
# 2    Tnfrsf19  TNFRSF19
# 3       Rspo3     RSPO3
# 4       Epha1     EPHA1
# ..        ...       ...
# 130      Cst3      CST3
# 131    Mogat2    MOGAT2
# 132  Serpinh1  SERPINH1
# 133       Sp5       SP5
# 134      Peg3      PEG3
#
# [135 rows x 2 columns]
# GSE201257_early    mmusculus hsapiens
# 0    Phactr1  PHACTR1
# 1      Map1b    MAP1B
# 2    Ppp1r1a  PPP1R1A
# 3    Spata13  SPATA13
# 4      Ednrb    EDNRB
# ..       ...      ...
# 93      Bmp7     BMP7
# 94     Celf2    CELF2
# 95    Arpc1b   ARPC1B
# 96     Gdpd5    GDPD5
# 97    Tom1l1   TOM1L1
#
# [98 rows x 2 columns]
# GSE201257_late    mmusculus hsapiens
# 0     Efemp2   EFEMP2
# 1      Vcam1    VCAM1
# 2    Smarca2  SMARCA2
# 3        Fos      FOS
# 4      Wnt5a    WNT5A
# ..       ...      ...
# 69   Tnfaip6  TNFAIP6
# 70    Pcolce   PCOLCE
# 71   Tmem119  TMEM119
# 72      Tbx2     TBX2
# 73     Mfap4    MFAP4
#
# [74 rows x 2 columns]
# GSE229103_early    mmusculus hsapiens
# 0      Greb1    GREB1
# 1       Cdx1     CDX1
# 2       Odc1     ODC1
# 3      Map1b    MAP1B
# 4       Rrm2     RRM2
# ..       ...      ...
# 78      Chd3     CHD3
# 79     Hoxb9    HOXB9
# 80     Hoxb8    HOXB8
# 81       Sp5      SP5
# 82    Tubb4b   TUBB4B
#
# [83 rows x 2 columns]
# GSE229103_late    mmusculus hsapiens
# 0       Fbn2     FBN2
# 1     Maged2   MAGED2
# 2      Rspo3    RSPO3
# 3      Wnt5a    WNT5A
# 4     Pcdh19   PCDH19
# ..       ...      ...
# 70    Rnf213   RNF213
# 71       Sct      SCT
# 72     Tcf15    TCF15
# 73      Peg3     PEG3
# 74     Nrarp    NRARP
#
# [75 rows x 2 columns]
# HCAEmbryonicHindlimb_early    hsapiens mmusculus
# 0   MT-ND4L   mt-Nd4l
# 1      CD24     Cd24a
# 2     WFDC2     Wfdc2
# 3      SOX9      Sox9
# 4       HBZ     Hba-x
# 5     MECOM     Mecom
# 6     PMP22     Pmp22
# 7    COL2A1    Col2a1
# 8    COL9A2    Col9a2
# 9       CPE       Cpe
# 10  ADAMTS6   Adamts6
# 11    HMGA1     Hmga1
# 12   COL9A1    Col9a1
# 13  RHOBTB3   Rhobtb3
# 14      MIA       Mia
# 15  S100A11   S100a11
# 16     CNN2      Cnn2
# 17     FRZB      Frzb
# 18  COL11A1   Col11a1
# HCAEmbryonicHindlimb_late    hsapiens mmusculus
# 0    MT-CO1    mt-Co1
# 1    MT-CO2    mt-Co2
# 2   MT-ATP6   mt-Atp6
# 3    MT-CO3    mt-Co3
# 4    MT-ND3    mt-Nd3
# ..      ...       ...
# 73   IGFBP4    Igfbp4
# 74     HES1      Hes1
# 75      BOC       Boc
# 76   COL3A1    Col3a1
# 77   COL5A2    Col5a2
#
# [78 rows x 2 columns]

# %%
top_signatures = {
    'PC1' : [
        'GSE162534_early',
        'GSE162534_late',
        'GSE201257_late',
        'GSE229103_late'
        ],
    'PC2' : [
        'GSE136689_early',
        'GSE136689_late',
        'GSE229103_early'
        ]
    }

# %%
for pc, signatures in top_signatures.items():
    gene_list = []
    for signature in signatures:
        gene_list.extend(signature_dict[signature].mmusculus.tolist())
    gene_list = sorted(set(gene_list))
    
    df = gp.enrichr(
        gene_list = gene_list,
        gene_sets = ['GO_Molecular_Function_2025'],
        organism = 'Mouse',
        outdir = None,
        cutoff = .05
        ).results[['Term', 'Adjusted P-value']]
    df['Term'] = df.Term.str.extract(r'\((GO:\d+)\)')
    df = df.loc[df['Adjusted P-value'] < .05].sort_values('Adjusted P-value')

    if df.empty:
        print(pc, 'No significant GO terms found.')
    else:
        df.to_csv(f'results/gseapy/{pc}.txt', index = False, sep = '\t')
        print(pc, df.head(), '\n')
# Out:
# PC1          Term  Adjusted P-value
# 0  GO:1990837      2.095216e-18
# 1  GO:0043565      7.238997e-17
# 2  GO:0003690      1.699094e-16
# 3  GO:0000977      2.413187e-11
# 4  GO:0000978      9.588516e-11
#
# PC2          Term  Adjusted P-value
# 0  GO:0043565      8.907472e-11
# 1  GO:1990837      1.674723e-10
# 2  GO:0003690      5.081938e-10
# 3  GO:0000977      1.184278e-09
# 4  GO:0000978      6.446386e-08

# %%
revigo_dict = top_signatures.copy()
for pc in revigo_dict:
    revigo_dict[pc] = pd.read_csv(f'results/revigo/{pc}.tsv', sep = '\t', index_col = 0)
    revigo_dict[pc] = revigo_dict[pc][revigo_dict[pc].Representative.isna()]
    print(pc, revigo_dict[pc])
# Out:
# PC1                                                          Name      Value  \
# TermID
# GO:0001228  DNA-binding transcription activator activity, ...  -5.609599
# GO:0004714  transmembrane receptor protein tyrosine kinase...  -4.703099
# GO:0005104          fibroblast growth factor receptor binding  -1.316386
# GO:0005109                                   frizzled binding  -2.513445
# GO:0005501                                   retinoid binding  -1.803079
# GO:0009008                     DNA-methyltransferase activity  -1.669648
# GO:0033550           MAP kinase tyrosine phosphatase activity  -1.669648
# GO:0045296                                   cadherin binding  -1.856368
# GO:0048018                           receptor ligand activity  -2.807382
# GO:0048407             platelet-derived growth factor binding  -2.238479
# GO:0070016                    armadillo repeat domain binding  -1.423038
# GO:0070696  transmembrane receptor protein serine/threonin...  -1.687472
# GO:0140297           DNA-binding transcription factor binding  -6.804694
# GO:1990837      sequence-specific double-stranded DNA binding -17.678771
#
#              LogSize  Frequency  Uniqueness  Dispensability  Representative
# TermID
# GO:0001228  2.603144   2.032211    0.948790       -0.000000             NaN
# GO:0004714  1.812913   0.325154    0.758202       -0.000000             NaN
# GO:0005104  1.342423   0.106691    0.861743        0.487420             NaN
# GO:0005109  1.431364   0.132094    0.859661        0.497534             NaN
# GO:0005501  1.518514   0.162577    0.969849        0.029499             NaN
# GO:0009008  0.903090   0.035564    0.896159        0.287879             NaN
# GO:0033550  0.301030   0.005081    0.850353        0.248816             NaN
# GO:0045296  1.462398   0.142255    0.871952        0.092627             NaN
# GO:0048018  2.704151   2.565666    0.745350        0.128152             NaN
# GO:0048407  1.041393   0.050805    0.904781        0.084308             NaN
# GO:0070016  0.845098   0.030483    0.937761        0.080711             NaN
# GO:0070696  1.278754   0.091449    0.863212        0.480371             NaN
# GO:0140297  2.610660   2.067774    0.809692        0.040207             NaN
# GO:1990837  2.936514   4.384494    0.703673        0.000000             NaN
# PC2                                                          Name     Value  \
# TermID
# GO:0001228  DNA-binding transcription activator activity, ... -5.228109
# GO:0002151                           G-quadruplex RNA binding -1.763617
# GO:0003779                                      actin binding -2.315742
# GO:0005109                                   frizzled binding -2.339570
# GO:0005324  long-chain fatty acid transmembrane transporte... -1.318395
# GO:0005501                                   retinoid binding -5.039665
# GO:0008330    protein tyrosine/threonine phosphatase activity -1.763617
# GO:0033293                        monocarboxylic acid binding -2.458800
# GO:0048018                           receptor ligand activity -2.458800
# GO:0061575  cyclin-dependent protein serine/threonine kina... -2.739940
# GO:0140297           DNA-binding transcription factor binding -1.765305
# GO:1990825                     sequence-specific mRNA binding -1.431541
# GO:1990837      sequence-specific double-stranded DNA binding -9.776057
#
#              LogSize  Frequency  Uniqueness  Dispensability  Representative
# TermID
# GO:0001228  2.603144   2.032211    0.990285       -0.000000             NaN
# GO:0002151  0.954243   0.040644    0.810111        0.289345             NaN
# GO:0003779  2.596597   2.001727    0.880060        0.040021             NaN
# GO:0005109  1.431364   0.132094    0.849070        0.497534             NaN
# GO:0005324  1.204120   0.076208    0.997990       -0.000000             NaN
# GO:0005501  1.518514   0.162577    0.896278        0.029499             NaN
# GO:0008330  0.602060   0.015242    0.954674       -0.000000             NaN
# GO:0033293  1.690196   0.243865    0.907976        0.030807             NaN
# GO:0048018  2.704151   2.565666    0.688537        0.494094             NaN
# GO:0061575  0.954243   0.040644    0.828365       -0.000000             NaN
# GO:0140297  2.610660   2.067774    0.856100        0.124068             NaN
# GO:1990825  1.079181   0.055886    0.805626        0.367351             NaN
# GO:1990837  2.936514   4.384494    0.603624        0.000000             NaN

# %%
# ix_shared = revigo_dict['PC1'].index.intersection(revigo_dict['PC2'].index)

# plot_df = pd.DataFrame({
#     'Description': revigo_dict['PC1'].loc[ix_shared, 'Name'],
#     'PC1': revigo_dict['PC1'].loc[ix_shared, 'Value'],
#     'PC2': revigo_dict['PC2'].loc[ix_shared, 'Value']
# })
# plot_df['mean'] = plot_df[['PC1', 'PC2']].mean(1)
# plot_df = plot_df.sort_values('mean')  # sort if you want clearer visual comparison

# # Plot paired bar plot
# plt.figure(figsize=(4, 6))
# x = range(len(plot_df))
# bar_width = 0.4

# plt.barh([i - bar_width/2 for i in x], plot_df['PC1'], height=bar_width, label='PC1')
# plt.barh([i + bar_width/2 for i in x], plot_df['PC2'], height=bar_width, label='PC2')

# plt.gca().invert_xaxis()
# plt.gca().invert_yaxis()
# plt.yticks(x, plot_df['Description'], ha='right')
# plt.xlabel('REVIGO Value')
# plt.title('Shared Representative GO Terms')
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# ix_shared = sorted(set(revigo_dict['PC1'].index) - set(revigo_dict['PC2'].index))

# plot_df = pd.DataFrame({
#     'Description': revigo_dict['PC1'].loc[ix_shared, 'Name'],
#     'PC1': revigo_dict['PC1'].loc[ix_shared, 'Value'],
#     # 'PC2': revigo_dict['PC2'].loc[ix_shared, 'Value']
# })
# # plot_df['mean'] = plot_df[['PC1', 'PC2']].mean(1)
# plot_df = plot_df.sort_values('PC1')  # sort if you want clearer visual comparison

# # Plot paired bar plot
# plt.figure(figsize=(4, 6))
# x = range(len(plot_df))
# bar_width = 0.4

# plt.barh([i - bar_width/2 for i in x], plot_df['PC1'], height=bar_width, label='PC1')
# # plt.barh([i + bar_width/2 for i in x], plot_df['PC2'], height=bar_width, label='PC2')

# plt.gca().invert_xaxis()
# plt.gca().invert_yaxis()
# plt.yticks(x, plot_df['Description'], ha='right')
# plt.xlabel('REVIGO Value')
# plt.title('Shared Representative GO Terms')
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# ix_shared = sorted(set(revigo_dict['PC2'].index) - set(revigo_dict['PC1'].index))

# plot_df = pd.DataFrame({
#     'Description': revigo_dict['PC2'].loc[ix_shared, 'Name'],
#     'PC2': revigo_dict['PC2'].loc[ix_shared, 'Value'],
#     # 'PC2': revigo_dict['PC2'].loc[ix_shared, 'Value']
# })
# # plot_df['mean'] = plot_df[['PC1', 'PC2']].mean(1)
# plot_df = plot_df.sort_values('PC2')  # sort if you want clearer visual comparison

# # Plot paired bar plot
# plt.figure(figsize=(4, 6))
# x = range(len(plot_df))
# bar_width = 0.4

# plt.barh([i - bar_width/2 for i in x], plot_df['PC2'], height=bar_width, label='PC2')
# # plt.barh([i + bar_width/2 for i in x], plot_df['PC2'], height=bar_width, label='PC2')

# plt.gca().invert_xaxis()
# plt.gca().invert_yaxis()
# plt.yticks(x, plot_df['Description'], ha='right')
# plt.xlabel('REVIGO Value')
# plt.title('Shared Representative GO Terms')
# plt.legend()
# plt.tight_layout()
# plt.show()
